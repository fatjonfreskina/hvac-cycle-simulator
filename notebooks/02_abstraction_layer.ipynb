# %% [markdown]
# ## In this notebook we're going to try to go from random CoolProp calls to something that builds on top of that.

# %%
import sys
sys.path.append("../src")

from thermo.state import get_state_PH
